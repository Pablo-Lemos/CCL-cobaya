# %%
# Imports
from getdist.mcsamples import loadMCSamples
import getdist.plots as gdplt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
gdsamples = loadMCSamples('./chains/cmblens', settings = {'ignore_rows':0.2})
# Out:
# WARNING:root:outlier fraction 0.0234375
# ./chains/cmblens.1.txt
# Removed 0.2 as burn in

# %%
p = gdplt.get_single_plotter(width_inch=6)
p.plot_2d(gdsamples, ["omch2", "As"], filled=True)
p.add_x_marker(0.122)
p.add_y_marker(2e-9)
#p.export('../plot/saved_plot')
